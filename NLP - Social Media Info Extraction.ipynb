# %% [markdown]
# # Import Libraries and Data

# %%
import pandas as pd
import re

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Demonatization_tweets.csv', encoding = 'unicode_escape', engine ='python')
df = df.set_index(df.columns[0])
df.head()
# Out:
#                                                          text
# Unnamed: 0
# 1           RT @rssurjewala: Critical question: Was PayTM ...
# 2           RT @Hemant_80: Did you vote on #Demonetization...
# 3           RT @roshankar: Former FinSec, RBI Dy Governor,...
# 4           RT @ANI_news: Gurugram (Haryana): Post office ...
# 5           RT @satishacharya: Reddy Wedding! @mail_today ...

# %% [markdown]
# # Get Top 50 Mentions by Count

# %%
mentions_list = list()

for i in range(len(df)):
    text = df['text'].iloc[i]
    mentions = re.findall('@\w+', text)
    for m in mentions:
        mentions_list.append(m)

mentions_list[0:3]
# Out:
# ['@rssurjewala', '@Hemant_80', '@roshankar']

# %%
mentions_df = pd.DataFrame(columns=['person', 'count'])
mentions_df['person'] = pd.Series(mentions_list).unique()
for i in range(len(mentions_df)):
    mentions_df['count'][i] = mentions_list.count(mentions_df['person'][i])
    
mentions_df = mentions_df.sort_values(by='count', ascending = False)
mentions_df[:51]
# Out:
#                 person count
# 1051      @evanspiegel  1311
# 1050  @URautelaForever  1273
# 11       @narendramodi  1138
# 8       @gauravcsawant   541
# 45        @ModiBharosa   540
# 113    @DrKumarVishwas   358
# 1072          @5Forty3   286
# 0         @rssurjewala   284
# 871      @rahulroushan   284
# 38           @PMOIndia   246
# 119     @centerofright   237
# 60      @ShashiTharoor   231
# 66     @DasShaktikanta   195
# 107    @ArvindKejriwal   185
# 408       @steve_hanke   179
# 50          @ashu3page   171
# 416           @YouTube   159
# 30          @kanimozhi   153
# 105       @RoflGandhi_   151
# 1229        @AskAnshul   149
# 1563          @Timcast   147
# 14    @Atheist_Krishna   135
# 310           @ippatel   116
# 12             @Joydas   114
# 89           @jamewils   114
# 29        @arunjaitley   114
# 65          @PIB_India   113
# 354       @FinMinIndia   104
# 1771    @attomeybharti   103
# 9         @Joydeep_911   102
# 2014  @PiyushGoyalOffc    95
# 1049        @Memeghnad    95
# 26         @DrGPradhan    90
# 223               @dna    85
# 1133  @priyaakulkarni2    80
# 1096   @arvindsubraman    80
# 27         @minimathur    79
# 353         @MIB_India    79
# 120          @Ra_THORe    75
# 17            @pGurus1    74
# 697      @_MiteshPatel    73
# 93           @aartic02    72
# 1566     @aaanupriyaaa    70
# 1274       @NG_withINC    68
# 277           @jairajp    62
# 1           @Hemant_80    62
# 32       @harshkkapoor    60
# 33                 @na    59
# 165     @ShirishKunder    56
# 61         @anandkamal    54
# 242       @anilkohli54    52

# %% [markdown]
# # Get Top 50 Hashtags by Count

# %%
hashtags_list = list()

for i in range(len(df)):
    text = df['text'].iloc[i]
    hashtags = re.findall('#\w+', text)
    for h in hashtags:
        hashtags_list.append(h.lower())

hashtags_list[0:10]
# Out:
# ['#demonetization',
#  '#demonetization',
#  '#demonetization',
#  '#demonetization',
#  '#demonetization',
#  '#reddywedding',
#  '#demonetization',
#  '#blackmoney',
#  '#demonetization',
#  '#corruptionfreeindia']

# %%
hashtags_df = pd.DataFrame(columns=['hashtag', 'count'])
hashtags_df['hashtag'] = pd.Series(hashtags_list).unique()
for i in range(len(hashtags_df)):
    hashtags_df['count'][i] = hashtags_list.count(hashtags_df['hashtag'][i])
    
hashtags_df = hashtags_df.sort_values(by='count', ascending = False)
hashtags_df[:51]
# Out:
#                      hashtag count
# 0            #demonetization  8652
# 28                    #india   378
# 20              #nitishkumar   258
# 813                    #demo   180
# 879                   #glvmi   145
# 2                #blackmoney   121
# 3       #corruptionfreeindia   103
# 48                     #modi    97
# 797             #vijaymallya    87
# 85           #demonetisation    86
# 56    #indiafightscorruption    79
# 49                      #bjp    57
# 112             #demonetizat    54
# 560             #nomoneyyaar    53
# 869               #sonunigam    49
# 904         #boycottsnapchat    46
# 180                #insights    44
# 81                #ratantata    44
# 391                #bulletin    44
# 6              #narendramodi    43
# 86                      #rbi    42
# 706           #lifeinsurance    34
# 1156          #youtubeisdead    30
# 160                   #nmapp    29
# 63                  #bypolls    29
# 805                 #youtube    28
# 9         #meradeshbadalraha    28
# 41                   #pmmodi    28
# 23              #netascashin    26
# 276                    #news    26
# 682                #trustbjp    25
# 916                #cgdtalks    24
# 273                     #not    23
# 24               #indiakadil    22
# 208                 #digital    21
# 275               #hilarious    21
# 778               #waroncash    20
# 274                  #hitler    20
# 118                   #delhi    20
# 126                    #cash    19
# 138                 #bitcoin    19
# 164                 #fintech    19
# 8                    #survey    19
# 777               #lifehacks    19
# 980                #snapchat    19
# 35                       #pm    19
# 218             #currencyban    18
# 279              #parliament    18
# 571                 #itvideo    18
# 489         #notenahipmbadlo    18
# 408                #payments    18

# %% [markdown]
# # Find Sentences Mentioning 'Prime Minister'

# %%
pms_sent_list = list()

for i in range(len(df)):
    text = df['text'].iloc[i]
    
    sent = re.findall('Prime Minister | \
                    Prime Minister\s\w+ | \
                    prime minister | \
                    prime minister\s\w+', text)
    
    if len(sent) > 0:
        pms_sent_list.append(text.lower())

len(pms_sent_list)
# Out:
# 61

# %% [markdown]
# There are 61 sentences mentioning 'prime minister'

# %%
pms_sent_list[0]
# Out:
# 'open message of #indian #child to prime minister #modi\r\n@narendramodi #demonetization #demonetisation https://t.co/xkf8ijnouc'

# %% [markdown]
# # Use the prepositions to extract relevant information from the tweets

# %% [markdown]
# A preposition is a word - almost always a small, common word - that shows direction, location, or time, or that introduces an object.
#
# - I sent a letter TO you -> to is a preposition showing direction
# - Someone is AT the door -> at is a preposition showing location
# - We will arrive BY noon -> by is a preposition showing time
#
# I'll start by viewing the POS tags for individual tweets, to see what tag corresponds to this type of word.

# %%
df = pd.read_csv('Demonatization_tweets.csv', encoding = 'unicode_escape', engine ='python')
df = df.set_index(df.columns[0])

# %% [markdown]
# Removing unwanted text:

# %%
for i in range(1, len(df)+1):
    df['text'][i] = re.sub('@\w+', "", df['text'][i]) # mentions
    df['text'][i] = re.sub('#\w+', "", df['text'][i]) # hastags
    df['text'][i] = re.sub('&amp;', "", df['text'][i]) # ampersands
    df['text'][i] = re.sub('RT\s:\s', "", df['text'][i]) # RT
    df['text'][i] = re.sub(r'http\S+', '', df['text'][i]) # links
    df['text'][i] = re.sub(r'http:\S+', '', df['text'][i]) # links
    df['text'][i] = re.sub("[^a-zA-Z]", " ", df['text'][i]) # symbols
    df['text'][i] = re.sub("\s\s", " ", df['text'][i]) # double spaces
    df['text'][i] = df['text'][i].lower() # lower case

# %%
df.head()
# Out:
#                                                          text
# Unnamed: 0
# 1           critical question was paytm informed about edi...
# 2                         did you vote on on modi survey app
# 3           former finsec rbi dy governor cbdt chair  harv...
# 4           gurugram haryana  post office employees provid...
# 5                                    reddy wedding  cartoon

# %%
import spacy
from spacy import displacy
nlp=spacy.load('en_core_web_sm')

# %%
text = df['text'][1]
doc=nlp(text)
for token in doc:
    print(token.text,'=>',token.pos_,'=>',token.tag_)
# Out:
# critical => ADJ => JJ
# question => NOUN => NN
# was => AUX => VBD
# paytm => PROPN => NNP
# informed => VERB => VBN
# about => ADP => IN
# edict => PROPN => NNP
# by => ADP => IN
# pm => NOUN => NN
# it => PRON => PRP
# s => VERB => VBZ
# clearly => ADV => RB
# fishy => ADJ => JJ
# and => CCONJ => CC
# requires => VERB => VBZ
# full => ADJ => JJ
# disclosure => NOUN => NN

# %% [markdown]
# The below shows that prepositional words like 'by' and 'about' have a POS label of 'ADP' (tag of 'IN'). It also shows how these words have a relationship to nouns (the noun follows).

# %%
displacy.render(doc,jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="7ebfbc29f86a41c78ce34a114f7300b6-0" class="displacy" width="3025" height="487.0" direction="ltr" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">critical</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">question</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">was</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">paytm</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">informed</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">about</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">edict</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">by</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">pm</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">it</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">s</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">clearly</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">fishy</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">requires</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">full</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">disclosure</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7ebfbc29f86a41c78ce34a114f7300b6-0-0" stroke-width="2px" d="M70,352.0 C70,264.5 210.0,264.5 210.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7ebfbc29f86a41c78ce34a114f7300b6-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,354.0 L62,342.0 78,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7ebfbc29f86a41c78ce34a114f7300b6-0-1" stroke-width="2px" d="M245,352.0 C245,89.5 745.0,89.5 745.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7ebfbc29f86a41c78ce34a114f7300b6-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubjpass</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,354.0 L237,342.0 253,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7ebfbc29f86a41c78ce34a114f7300b6-0-2" stroke-width="2px" d="M420,352.0 C420,177.0 740.0,177.0 740.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7ebfbc29f86a41c78ce34a114f7300b6-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">auxpass</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,354.0 L412,342.0 428,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7ebfbc29f86a41c78ce34a114f7300b6-0-3" stroke-width="2px" d="M595,352.0 C595,264.5 735.0,264.5 735.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7ebfbc29f86a41c78ce34a114f7300b6-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">npadvmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M595,354.0 L587,342.0 603,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7ebfbc29f86a41c78ce34a114f7300b6-0-4" stroke-width="2px" d="M770,352.0 C770,264.5 910.0,264.5 910.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7ebfbc29f86a41c78ce34a114f7300b6-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M910.0,354.0 L918.0,342.0 902.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7ebfbc29f86a41c78ce34a114f7300b6-0-5" stroke-width="2px" d="M945,352.0 C945,264.5 1085.0,264.5 1085.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7ebfbc29f86a41c78ce34a114f7300b6-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1085.0,354.0 L1093.0,

# %% [markdown]
# Using the first tweet, we see that:
# - 'about' is a preposition followed by the word 'edict'
# - 'by' is a preposition followed by the word 'pm'

# %%
text = df['text'][1]
print(text)
doc=nlp(text)

counter = 1

for token in doc:
    if token.pos_ == 'ADP':
        print(token.text, token.pos_, token.tag_)
        print(doc[counter])
    counter = counter + 1
# Out:
# critical question was paytm informed about edict by pm it s clearly fishy and requires full disclosure
# about ADP IN
# edict
# by ADP IN
# pm

# %% [markdown]
# We can create a list of words following prepositions...

# %%
object_list = []

for i in range(1,len(df)+1):
    text = df['text'][i]
    doc=nlp(text)
    counter = 1
    for token in doc:
        if token.pos_ == 'ADP':
            try:
                object_list.append(doc[counter])
            except:
                pass
        counter = counter + 1

# %%
objects_df = pd.DataFrame(columns=['entity', 'count'])
objects_df['entity'] = pd.Series(object_list).unique()

for i in range(len(objects_df)):
    objects_df['count'][i] = object_list.count(objects_df['entity'][i])

objects_df[objects_df['entity'] != ""].head()
# Out:
#   entity count
# 0  edict     1
# 1     pm     1
# 2     on     1
# 3   modi     1
# 4    aam     1
